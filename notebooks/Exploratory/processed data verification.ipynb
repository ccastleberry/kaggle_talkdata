# %%
% cd ..
# Out:
# /Users/calebcastleberry/Documents/GitHub/kaggle_talkdata/notebooks

# %%
% cd ..
# Out:
# /Users/calebcastleberry/Documents/GitHub/kaggle_talkdata

# %%
import pandas as pd
import os

# %%
data_path = os.path.join('data', 'processed')
train_path = os.path.join(data_path, 'train1.csv')

# %%
train_df = pd.read_csv(train_path)

# %%
train_df.head()
# Out:
#    app  channel  click_id  device      ip  is_attributed  os  hour  day  X0  \
# 0    3      379       NaN       1   83230            0.0  13    14    6   1
# 1    3      379       NaN       1   17357            0.0  19    14    6   3
# 2    3      379       NaN       1   35810            0.0  13    14    6   1
# 3   14      478       NaN       1   45745            0.0  13    14    6  15
# 4    3      379       NaN       1  161007            0.0  13    14    6   1
#
#         ...         ip_tcount  ip_app_count  ip_app_os_count  ip_tchan_count  \
# 0       ...                 1             1                1             0.0
# 1       ...                 1             3                2             0.5
# 2       ...                 1             1                1             0.0
# 3       ...                 1             4                2             0.0
# 4       ...                 1             1                1             0.0
#
#    ip_app_os_var  ip_app_channel_var_day  ip_app_channel_mean_hour  \
# 0            0.0                     0.0                      14.0
# 1           40.5                     0.0                      14.5
# 2            0.0                     0.0                      14.0
# 3            2.0                     0.0                      14.0
# 4            0.0                     0.0                      14.0
#
#    ip_app_channel_mean_attrib     nextClick  nextClick_shift
# 0                         0.0  1.490021e+09     0.000000e+00
# 1                         0.0  2.259710e+05     1.490021e+09
# 2                         0.0  1.490021e+09     2.259710e+05
# 3                         0.0  5.110000e+03     1.490021e+09
# 4                         0.0  1.490021e+09     5.110000e+03
#
# [5 rows x 28 columns]
